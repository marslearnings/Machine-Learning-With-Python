# %% [markdown]
# # One hashtag in markdown is header 1 - h1
# ## Two hashtag is header 2 - h2
# ### This is header 3 (contains 3 hashtags)
# #### This is header 4 (contains 4 hashtags)

# %% [markdown]
# This is paragrag if there is no hashtags

# %% [markdown]
# **bold text**

# %% [markdown]
# *italicized text*

# %% [markdown]
# > blockquote

# %% [markdown]
# 1. First item
# 2. Second item
# 3. Third item

# %% [markdown]
# 'code'

# %% [markdown]
# ---

# %% [markdown]
# [title](https://www.example.com)

# %%
![alt text](image.jpg)

# %% [markdown]
# | Syntax | Description |
# | ----------- | ----------- |
# | Header | Title |
# | Paragraph | Text |

# %%
```
{
  "firstName": "John",
  "lastName": "Smith",
  "age": 25
}
  ```

# %%
Here's a sentence with a footnote. [^1]

[^1]: This is the footnote.

# %% [markdown]
# ### My Great Heading {myid}

# %%
term
: definition

# %%
~~The world is flat.~~

# %% [markdown]
# - [x] Write the press release
# - [ ] Update the website
# - [ ] Contact the media

# %% [markdown]
# That is so funny! :joy:

# %% [markdown]
# I need to highlight these ==very important words==

# %% [markdown]
# H_2O

# %%
X^2^
