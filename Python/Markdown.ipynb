# %% [markdown]
# # This is header 1 (h1 in html)
# ## This is header 2
# ### This is header 3
# #### this is header 4
# ##### this is header 5
# ###### this is header 6
# This is a paragragh (p tag in html)
#
# ##### always maintain the space after hashtag to get markdown view

# %% [markdown]
# ### Getting Started
# **Python** can be easy to pick up whether you're a first time programmer or you're experienced with other languages. The following pages are a useful first step to get on your way writing programs with Python!
#
# - **Beginner's Guide, Programmers**
# - *Beginner's Guide, Non-Programmers*
# - ***Beginner's Guide, Download & Installation***
# - ~~Code sample and snippets for Beginners~~

# %% [markdown]
# ### Applications
# The Python Package Index ([PyPI](https://pypi.org/)) hosts thousands of third-party modules for Python. Both Python's standard library and the community-contributed modules allow for endless possibilities.
#
# 1. Web and Internet Development
# 1. Database Access
# 2. Desktop GUIs
# 1. Scientific & Numeric
# 1. Education
# 4. Network Programming
# 1. Software & Game Development
#
# > To create blockquote we need to use angle brackets (>)
# >> This is sub of blockquote
#
# ##### We create also create nested list either ordered or unordered by -, nested (\t and -)
#
# #### Refrences of Python
# - [Google](https://www.google.com/)
#     - Stackoverflow
#         - W3schools
#             - ChatGPT
#
# ---

# %% [markdown]
# we can display image in markdown syntax is ![](path of the image )
#
# ![image](Python-Logo.jpg)

# %% [markdown]
# ![image.png](attachment:66e8489f-444a-453d-8d98-8eb1a7e5f38a.png)
