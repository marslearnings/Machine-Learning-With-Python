# %% [markdown]
# # Dictionaries
# - Key value pair

# %%
# {}, dict
my_dict = {
    "key1": "value1",
    "key2": "value2",
    "key3": "value3",
    "key4": "value4"
}
List = ['value1','value2','value3','value4']

# %%
my_dict['key1']
# Out:
# 'value1'

# %%
List[0]
# Out:
# 'value1'

# %%
# cricket world cup winner
wcWinners = { 1975: "West Indies",
1979: "West Indies",
1983: "India",
1987: "Australia",
1991: "Pakistan",
1996: "Sri Lanka",
1999: "Australia",
2003: "Australia",
2007: "Australia",
2011: "India",
2015: "Australia",
2019: "England",
2024: "Australia"}
print(wcWinners)
# Out:
# {1975: 'West Indies', 1979: 'West Indies', 1983: 'India', 1987: 'Australia', 1991: 'Pakistan', 1996: 'Sri Lanka', 1999: 'Australia', 2003: 'Australia', 2007: 'Australia', 2011: 'India', 2015: 'Australia', 2019: 'England', 2024: 'Australia'}

# %% [markdown]
# 1. Find winner of 2015
# 2. List of countries won World Cup
# 3. Which country won most of the world cups
# 4. In which year India won last world cup

# %%
wcWinners[2015]
# Out:
# 'Australia'

# %%
# List of countries won World Cup
keylist = wcWinners.keys()
valuelist = wcWinners.values()

print(keylist)
print(valuelist)
# Out:
# dict_keys([1975, 1979, 1983, 1987, 1991, 1996, 1999, 2003, 2007, 2011, 2015, 2019, 2024])
# dict_values(['West Indies', 'West Indies', 'India', 'Australia', 'Pakistan', 'Sri Lanka', 'Australia', 'Australia', 'Australia', 'India', 'Australia', 'England', 'Australia'])

# %%
set(valuelist)
# Out:
# {'Australia', 'England', 'India', 'Pakistan', 'Sri Lanka', 'West Indies'}

# %%
# Which country won most of the world cups
from collections import Counter

# %%
Counter(valuelist)
# Out:
# Counter({'Australia': 6,
#          'West Indies': 2,
#          'India': 2,
#          'Pakistan': 1,
#          'Sri Lanka': 1,
#          'England': 1})

# %%
# In which year India won last world cup

# %% [markdown]
# ### methods

# %%
wcWinners.get(2011)
# Out:
# 'India'

# %%
wcWinners[2011]
# Out:
# 'India'

# %%
wcWinners.items()
# Out:
# dict_items([(1975, 'West Indies'), (1979, 'West Indies'), (1983, 'India'), (1987, 'Australia'), (1991, 'Pakistan'), (1996, 'Sri Lanka'), (1999, 'Australia'), (2003, 'Australia'), (2007, 'Australia'), (2011, 'India'), (2015, 'Australia'), (2019, 'England'), (2024, 'Australia')])

# %%
for key, value in wcWinners.items():
    print('key =', key, "value =", value)
# Out:
# key = 1975 value = West Indies
# key = 1979 value = West Indies
# key = 1983 value = India
# key = 1987 value = Australia
# key = 1991 value = Pakistan
# key = 1996 value = Sri Lanka
# key = 1999 value = Australia
# key = 2003 value = Australia
# key = 2007 value = Australia
# key = 2011 value = India
# key = 2015 value = Australia
# key = 2019 value = England
# key = 2024 value = Australia

# %%
wcWinners
# Out:
# {1975: 'West Indies',
#  1979: 'West Indies',
#  1983: 'India',
#  1987: 'Australia',
#  1991: 'Pakistan',
#  1996: 'Sri Lanka',
#  1999: 'Australia',
#  2003: 'Australia',
#  2007: 'Australia',
#  2011: 'India',
#  2015: 'Australia',
#  2019: 'England',
#  2024: 'Australia'}

# %%
wcWinners.update({2029: "TBD"})

# %%
wcWinners
# Out:
# {1975: 'West Indies',
#  1979: 'West Indies',
#  1983: 'India',
#  1987: 'Australia',
#  1991: 'Pakistan',
#  1996: 'Sri Lanka',
#  1999: 'Australia',
#  2003: 'Australia',
#  2007: 'Australia',
#  2011: 'India',
#  2015: 'Australia',
#  2019: 'England',
#  2024: 'Australia',
#  2029: 'TBD'}

# %%
wcWinners.update({2011: "BHARATH"})
wcWinners
# Out:
# {1975: 'West Indies',
#  1979: 'West Indies',
#  1983: 'India',
#  1987: 'Australia',
#  1991: 'Pakistan',
#  1996: 'Sri Lanka',
#  1999: 'Australia',
#  2003: 'Australia',
#  2007: 'Australia',
#  2011: 'BHARATH',
#  2015: 'Australia',
#  2019: 'England',
#  2024: 'Australia',
#  2029: 'TBD',
#  '2011': 'BHARATH'}
