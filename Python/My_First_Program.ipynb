# %%
a = 2

# %%
b= 3

# %%
c= a + b

# %%
print(a)
# Out:
# 2

# %%
print("The values of a =", a)
print('The value of b =', b)
print('a + b =', c)
# Out:
# The values of a = 2
# The value of b = 3
# a + b = 5

# %% [markdown]
# # Declaring Variables
