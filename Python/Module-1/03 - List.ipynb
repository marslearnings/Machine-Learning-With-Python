# %% [markdown]
# # List
# - It is a sequence and collection of different data types
# - It is mutable (Changeable)

# %% [markdown]
#  Denoted by    `[ ]`

# %%
text1 = 'A B C D E F'
text2 = 'ABCDEF'

# %%
# conversion from string to list
a = text1.split(sep=' ')
a
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %% [markdown]
# # join

# %%
"?".join(a) #
# Out:
# 'A?B?C?D?E?F'

# %%
# data type 
type(a)
# Out:
# list

# %% [markdown]
# # Creating List
#  - we can create list with a square braces  [ ]

# %%
mylist = ['innomatics','technology',10,25.0,True,False]
# it is mixture of datatypes

# %%
mylist
# Out:
# ['innomatics', 'technology', 10, 25.0, True, False]

# %%
# len of list
len(mylist)
# Out:
# 6

# %% [markdown]
# - print first element
# - print second element
# - print last element
# - print first three elements
# - print last three elements
# - print alternate elements in mylist
# - print every 3rd element in mylist
# - print mylist in reverse order

# %%
# print first element
mylist[0]
# Out:
# 'innomatics'

# %%
# second element , last element
mylist[1], mylist[-1]
# Out:
# ('technology', False)

# %%
# first three elements
print(mylist[:3])

# last three
print(mylist[-3:])
# Out:
# ['innomatics', 'technology', 10]
# [25.0, True, False]

# %%
mylist
# Out:
# ['innomatics', 'technology', 10, 25.0, True, False]

# %%
# alternate elements
print(mylist[::2])
# every 3rd elements
print(mylist[::3])
# reverse
print(mylist[::-1])
# Out:
# ['innomatics', 10, True]
# ['innomatics', 25.0]
# [False, True, 25.0, 10, 'technology', 'innomatics']

# %% [markdown]
# # Methods

# %%
mylist
# Out:
# ['innomatics', 'technology', 10, 25.0, True, False]

# %%
# append 
# i want to append "nizampet"
mylist.append("nizampet")
print(mylist)
# Out:
# ['innomatics', 'technology', 10, 25.0, True, False, 'nizampet', 'hyd', ['hyd', 'nizampet'], 'nizampet', 'nizampet']

# %%
# apped hyderabad into mylist
mylist.append('hyd')

# %%
print(mylist)
# Out:
# ['innomatics', 'technology', 10, 25.0, True, False, 'nizampet', 'hyd']

# %%
# append list
mylist.append(['hyd','nizampet'])
print(mylist)
# Out:
# ['innomatics', 'technology', 10, 25.0, True, False, 'nizampet', 'hyd', ['hyd', 'nizampet']]

# %% [markdown]
# nested list
# - within the list there is a list

# %%
mylist[-1][0][1]
# Out:
# 'y'

# %%
# convert into markdown

# %%
#mylist.clear()

# %%
print(mylist)
# Out:
# ['innomatics', 'technology', 10, 25.0, True, False, 'nizampet', 'hyd', ['hyd', 'nizampet'], 'nizampet', 'nizampet']

# %%
mylist.count(['hyd','nizampet'])
# Out:
# 1

# %%
mylist.extend(['hyd','nizampet'])

# %%
print(mylist)
# Out:
# ['innomatics', 'technology', 10, 25.0, True, False, 'nizampet', 'hyd', ['hyd', 'nizampet'], 'nizampet', 'nizampet', 'hyd', 'nizampet']

# %%
mylist.remove('nizampet')

# %%
print(mylist)
# Out:
# ['innomatics', 'technology', 10, 25.0, True, False, 'hyd', ['hyd', 'nizampet'], 'nizampet', 'nizampet', 'hyd', 'nizampet']

# %%
mylist.pop()
# Out:
# 'nizampet'

# %%
print(mylist)
# Out:
# ['innomatics', 'technology', 10, 25.0, True, False, 'hyd', ['hyd', 'nizampet'], 'nizampet', 'nizampet', 'hyd']

# %%
mylist.pop(4)
# Out:
# True

# %%
print(mylist)
# Out:
# ['innomatics', 'technology', 10, 25.0, False, 'hyd', ['hyd', 'nizampet'], 'nizampet', 'nizampet', 'hyd']

# %%
# finding index position
mylist.index(10)
# Out:
# 2

# %%
mylist.insert(3,'Srikanth')
print(mylist)
# Out:
# ['innomatics', 'technology', 10, 'Srikanth', 25.0, False, 'hyd', ['hyd', 'nizampet'], 'nizampet', 'nizampet', 'hyd']

# %%
# mylist2

mylist2 = ['Name','28','Age','Srikanth','DS','Designation',
           'Nizampet','Location']
print(mylist2)
# Out:
# ['Name', '28', 'Age', 'Srikanth', 'DS', 'Designation', 'Nizampet', 'Location']

# %%
mylist2.insert(1,mylist2.pop(3))

# %%
mylist2
# Out:
# ['Name', 'Srikanth', '28', 'Age', 'DS', 'Designation', 'Nizampet', 'Location']

# %%
" ".join(mylist2[:3])
# Out:
# 'Name Srikanth 28'

# %%
mylist2
# Out:
# ['Name', 'Srikanth', 'Desgination', 'DS', 'Age', '28', 'Location', 'Nizampet']

# %%
type(text1)
# Out:
# str

# %%
type(text2)
# Out:
# str

# %% [markdown]
# # converting string to List    Method 1

# %%
# string to list
text1.split()
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
text2.split()
# Out:
# ['ABCDEF']

# %%
text2.split('C')
# Out:
# ['AB', 'DEF']

# %% [markdown]
# # `list` ()  # Method 2

# %%
text2
# Out:
# 'ABCDEF'

# %%
list(text2)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
text1
# Out:
# 'A B C D E F'

# %%
list(text1)
# Out:
# ['A', ' ', 'B', ' ', 'C', ' ', 'D', ' ', 'E', ' ', 'F']

# %% [markdown]
# # create a list using [ ]

# %%
# [ ]
my_list = ['Innomatics','Technology','Hub',1,2,3,5.5,True,False]
my_list
# Out:
# ['Innomatics', 'Technology', 'Hub', 1, 2, 3, 5.5, True, False]

# %%
my_list
# Out:
# ['Innomatics', 'Technology', 'Hub', 1, 2, 3, 5.5, True, False]

# %% [markdown]
# # Indexing
# - print 1st element
# - print last element
# - print 1st three elements
# - print last three elements
# - print alternate elements starting with Innomatics
# - print alternate elements starting with Technology
# - print my_list reverse order

# %%
# 1st element
print('='*20)
print('1st element: ',my_list[0])
print('='*20)
# last element
print('='*20)
print('last element: ',my_list[-1])
print('='*20)
# 1st three elements
print('='*20)
print('1st three elements: ',my_list[0:3]) # :3 , :3:1, 0:3:1
print('='*20)
# last three elements
print('='*20)
print('last three elements: ',my_list[-3:]) #  
print('='*20)
# alternate elements
print('='*20)
print('alternate elements: {}'.format(my_list[0::2])) # ::2, 0:len(my_list):2  
print('='*20)
# alternate elements
print('='*20)
print('alternate elements technology: %s'% my_list[1::2]) #  
print('='*20)
# Reverse order
print('='*20)
print('Reverse order: %s'% my_list[::-1]) #  
print('='*20)
# Out:
# ====================
# 1st element:  Innomatics
# ====================
# ====================
# last element:  False
# ====================
# ====================
# 1st three elements:  ['Innomatics', 'Technology', 'Hub']
# ====================
# ====================
# last three elements:  [5.5, True, False]
# ====================
# ====================
# alternate elements: ['Innomatics', 'Hub', 2, 5.5, False]
# ====================
# ====================
# alternate elements technology: ['Technology', 1, 3, True]
# ====================
# ====================
# Reverse order: [False, True, 5.5, 3, 2, 1, 'Hub', 'Technology', 'Innomatics']
# ====================

# %%
my_list[0:]
# Out:
# ['Innomatics', 'Technology', 'Hub', 1, 2, 3, 5.5, True, False]

# %%
my_list[:]
# Out:
# ['Innomatics', 'Technology', 'Hub', 1, 2, 3, 5.5, True, False]

# %%
my_list[-1:]
# Out:
# [False]

# %%
my_list[-9:]
# Out:
# ['Innomatics', 'Technology', 'Hub', 1, 2, 3, 5.5, True, False]

# %%
my_list[:-2]
# Out:
# ['Innomatics', 'Technology', 'Hub', 1, 2, 3, 5.5]

# %% [markdown]
# # Methods

# %%
# Create a list 'Name' , 'Place', 'Location' , 'Time'
details = ['Name','Place','Location','Time']
details
# Out:
# ['Name', 'Place', 'Location', 'Time']

# %% [markdown]
# `append` : joining

# %%
# method 1 for appending
details.append('Srikanth')
details
# Out:
# ['Name', 'Place', 'Location', 'Time', 'Srikanth']

# %%
details.append(["Raghu", "Ram"])
details
# Out:
# ['Name',
#  'Place',
#  'Location',
#  'Time',
#  ['Raghu', 'Ram'],
#  ['Raghu', 'Ram'],
#  ['Raghu', 'Ram']]

# %%
# Method2 '+'
# In place of appeding we can use +
details_1 = details + ['Hyd']
details_1
# Out:
# ['Name',
#  'Srikanth',
#  'Place',
#  'Hyderabad',
#  'Location',
#  'Nizampet',
#  'Time',
#  '11.40',
#  'Hyd']

# %%
details
# Out:
# ['Name', 'Place', 'Location', 'Time', 'Srikanth']

# %% [markdown]
# ***Note: L.append() it will take only one argument or object or element*

# %%
# using append method, concatenate place location and Time
details.append(['Hyderabad','Nizampet'])

# %%
details
# Out:
# ['Name', 'Place', 'Location', 'Time', 'Srikanth', ['Hyderabad', 'Nizampet']]

# %%
app = ['Hyderabad','Nizampet']
for i in app:
    details.append(i)
print(details)
# Out:
# ['Name', 'Place', 'Location', 'Time', 'Srikanth', ['Hyderabad', 'Nizampet'], 'Hyderabad', 'Nizampet']

# %%
details.extend(['Hyderabad','Nizampet'])
print(details)
# Out:
# ['Name', 'Place', 'Location', 'Time', 'Srikanth', ['Hyderabad', 'Nizampet'], 'Hyderabad', 'Nizampet', 'Hyderabad', 'Nizampet']

# %%
# 
details.append('11.30')
print(details)
# Out:
# ['Name', 'Place', 'Location', 'Time', 'Srikanth', ['Hyderabad', 'Nizampet'], 'Hyderabad', 'Nizampet', 'Hyderabad', 'Nizampet', '11.30']

# %%
# 
details.count('Hyderabad')
# Out:
# 2

# %%
details.index('Hyderabad',8)
# Out:
# 8

# %%
# pop last in first out 
details.pop()# will remove last element
# Out:
# '11.30'

# %%
print(details)
# Out:
# ['Name', 'Place', 'Location', 'Time', 'Srikanth', ['Hyderabad', 'Nizampet'], 'Hyderabad', 'Nizampet', 'Hyderabad', 'Nizampet']

# %%
details.pop(5)# will remove last element
# Out:
# ['Hyderabad', 'Nizampet']

# %%
print(details)
# Out:
# ['Name', 'Place', 'Location', 'Time', 'Srikanth', 'Hyderabad', 'Nizampet', 'Hyderabad', 'Nizampet']

# %%
# remove
details.remove('Hyderabad')
print(details)
# Out:
# ['Name', 'Place', 'Location', 'Time', 'Srikanth', 'Nizampet', 'Hyderabad', 'Nizampet']

# %%
# insert
lprint(details)
# Out:
# ['Name', 'Place', 'Location', 'Time', '11.40', 'Srikanth', 'Nizampet', 'Hyderabad', 'Nizampet']

# %%
print(details)
# Out:
# ['Name', 'Place', 'Location', 'Time', '11.40', 'Srikanth', 'Nizampet', 'Hyderabad', 'Nizampet']

# %%
# make use of above details list , write a program to insert
# your name after 'Name' , place after 'Place' and so on

# %%
details.insert(1,details.pop(5))

# %%
print(details)
# Out:
# ['Name', 'Srikanth', 'Place', 'Location', 'Time', '11.40', 'Nizampet', 'Hyderabad', 'Nizampet']

# %%
details.insert(3,details.pop(7))
details
# Out:
# ['Name',
#  'Srikanth',
#  'Place',
#  'Hyderabad',
#  'Location',
#  'Time',
#  '11.40',
#  'Nizampet',
#  'Nizampet']

# %%
details.insert(5,details.pop())
details.pop()
print(details)
# Out:
# ['Name', 'Srikanth', 'Place', 'Hyderabad', 'Location', 'Nizampet', 'Time', '11.40']
